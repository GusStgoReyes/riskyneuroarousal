# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pupil = pd.read_csv("../../../../PAPERS/paper1_loss_aversion_pupil/eye_data/NARPS_MG_asc_processed/sub-003_run-3_timeseries_start2.csv")

# %%
pupil
# Out:
#       sub  run  time_orig  pupil_raw_deblink_detransient_interpolate_lpfilt  \
# 0       3    3    1820353                                       4760.066961
# 1       3    3    1820477                                       4756.546272
# 2       3    3    1820603                                       4753.031698
# 3       3    3    1820727                                       4749.524296
# 4       3    3    1820853                                       4746.025071
# ...   ...  ...        ...                                               ...
# 3590    3    3    2269037                                       5099.057498
# 3591    3    3    2269161                                       5097.830928
# 3592    3    3    2269287                                       5096.582603
# 3593    3    3    2269411                                       5095.319307
# 3594    3    3    2269537                                       5094.735469
#
#       blink  outofbounds
# 0       1.0          1.0
# ...

# %%
sns.lineplot(data=pupil, x="time_orig", y="pupil_raw_deblink_detransient_interpolate_lpfilt")
plt.xlim(1820353+24000, 1820353 + 32000)
# Out:
# (1844353.0, 1852353.0)

# %%
sns.lineplot(data=pupil, x="time_orig", y="outofbounds", lw = 0.5)
# Out:
# <Axes: xlabel='time_orig', ylabel='outofbounds'>

# %%
np.mean(pupil["blink"])
# Out:
# np.float64(0.3615509679128504)
