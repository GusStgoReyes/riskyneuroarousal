# %%
from utils.load_data import load_behavioral_data

# %%
behavioral_data = load_behavioral_data(min_RT = 0.2)

# %%
behavioral_data
# Out:
#        sub  run          condition  gain  loss     RT  accept  response_int  \
# 0        1    1  equalIndifference    14     6  2.388       1           3.0
# 1        1    1  equalIndifference    34    14  2.289       1           4.0
# 2        1    1  equalIndifference    34    13  1.873       1           4.0
# 3        1    1  equalIndifference    10    10  1.457       0           2.0
# 4        1    1  equalIndifference    12    19  1.973       0           1.0
# ...    ...  ...                ...   ...   ...    ...     ...           ...
# 27643  124    4         equalRange     7    14  1.235       0           1.0
# 27644  124    4         equalRange     5     9  1.236       0           1.0
# 27645  124    4         equalRange     5    15  1.030       0           1.0
# 27646  124    4         equalRange    12    18  1.029       0           1.0
# 27647  124    4         equalRange     6    16  0.926       0           1.0
#
#       participant_response  trial
# ...
